# %% [markdown]
# # Function Python
#
# ### O que é?
#
# As functions são blocos de código que servem 1 único propósito, fazem uma ação específica.
#
# ### Estrutura Básica

# %% [raw]
# def nome_funcao():
#     faça alguma coisa
#     faça outra coisa
#     return valor_final

# %% [markdown]
# - Exemplo: vamos criar uma função de cadastro de um Produto. Essa função deve garantir que o produto cadastrado está em letra minúscula.

# %%
def cadastrar_produto():
    produto= input("Digite um produto")
    produto= produto.casefold() # organiza tudo em minusculo
    produto=produto.strip() # retira os espaços caso for digitado no input
    print(f"Produto {produto} cadastrado com sucesso")

# %%
for i in range(5):
    cadastrar_produto()

# %% [markdown]
# Retornar um valor em python

# %%
def cadastrar_produto():
    produto= input("Digite um produto")
    produto= produto.casefold() # organiza tudo em minusculo
    produto=produto.strip() # retira os espaços caso for digitado no input
    return produto

# %%
variavel_produto= cadastrar_produto()
print(variavel_produto)
# Out:
# feijão
