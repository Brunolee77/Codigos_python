# %% [markdown]
# # Algumas Funções Básicas de Lista
#
# ## Tamanho da Lista
#
# tamanho = len(lista)

# %%
produtos = ['apple tv', 'mac', 'iphone x', 'IPad', 'apple watch', 'mac book', 'airpods']

# %% [markdown]
# - Quantos produtos temos a venda?

# %%
tamanho=len(produtos)
print(tamanho)
# Out:
# 7

# %% [markdown]
# ## Maior e Menor Valor
#
# maior = max(lista)
#
# menor = min(lista)

# %%
vendas = [1000, 1500, 15000, 270, 900, 100, 1200]

# %% [markdown]
# - Qual o item mais vendido?
# - Qual o item menos vendido?

# %%
mais_vendido=max(vendas)
menos_vendido=min(vendas)

print(f"O produto mais vendido foi {mais_vendido} unidades venditas")
print(f"O produto menos vendido foi {menos_vendido} unidades vendidas")
# Out:
# O produto mais vendido foi 15000 unidades venditas
# O produto menos vendido foi 100 unidades vendidas

# %%
# se eu quiser descobrir qual é o produto mais e menos vendido e não só os numeros. posso utilizar o index



i=vendas.index(mais_vendido)
produto_mais_vendido=produtos[i]
print(produto_mais_vendido)

i=vendas.index(menos_vendido)
produto_menos_vendido=produtos[i]
print(produto_menos_vendido)
# Out:
# iphone x
# mac book
