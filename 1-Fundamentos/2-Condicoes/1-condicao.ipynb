# %%
meta= 50000
qtde_vendida= 60000

if qtde_vendida > meta:
    print("Batemos a meta de venda de iphone ,vendemos {} unidades".format(qtde_vendida))
# Out:
# Batemos a meta de venda de iphone ,vendemos 60000 unidades

# %%
meta = 50000
qtde_vendida = 5300
if qtde_vendida > meta:
    print("Batemos a meta de venda de iphone ,vendemos {} unidades".format(qtde_vendida))

else:
    print("Infelizmente não batemos a meta, vendemos {} unidades, a meta era de {} unidades ".format(qtde_vendida,meta))
# Out:
# Infelizmente não batemos a meta, vendemos 5300 unidades, a meta era de 50000 unidades

# %%
meta= 0.05
taxa = 0
rendimento= 0.25

if  rendimento > meta:
    if rendimento > 0.20:
        taxa= 0.04
        print("A taxa foi de {}".format(taxa))
    else:
        taxa = 0.02
        (print("A taxa foi de {}".format(taxa)))
else:
    taxa=0
    print("A taxa foi de {}".format(taxa))
# Out:
# A taxa foi de 0.04
